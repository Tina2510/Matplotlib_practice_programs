# %% [markdown]
# 1 [Write a Python programming to create a pie chart of the popularity of programming
# Languages]

# %%
import matplotlib.pyplot as plt
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.pie(popularity, labels=languages)
plt.title("Popularity of Programming Languages")
plt.show()

# %% [markdown]
# 2 Write a Python programming to create a pie chart with a title of the popularity of programming langauges

# %%
import matplotlib.pyplot as plt
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.figure()
plt.pie(popularity, labels=languages, autopct='%1.1f%%', startangle=140)
plt.title('Popularity of Programming Languages')
plt.show()

# %% [markdown]
# 3 a pie chart of gold medal achievements of five most successful countries in 2016 Summer Olympics

# %%
import matplotlib.pyplot as plt
import csv

countries = []
gold_medals = []
with open('medal.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        countries.append(row['country'])
        gold_medals.append(int(row['gold_medal']))
plt.figure()
plt.pie(gold_medals, labels=countries, autopct='%1.1f%%', startangle=140)
plt.title('Gold Medal Achievements - 2016 Summer Olympics')
plt.show()
